# %%
import pandas as pd

data = pd.read_csv("Causes_of_Death_2026.csv")
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2102 entries, 0 to 2101
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     2102 non-null   int64
#  1   Leading Cause            2102 non-null   str
#  2   Sex                      2102 non-null   str
#  3   Race Ethnicity           2102 non-null   str
#  4   Deaths                   2102 non-null   str
#  5   Death Rate               1759 non-null   str
#  6   Age Adjusted Death Rate  1759 non-null   str
# dtypes: int64(1), str(6)
# memory usage: 115.1 KB
